# %%
#Corine Smith, Homework 8, Mar 10 09:14:20 EST 2022
print( "Start of Homework 8")
# Out:
# Start of Homework 8

# %%
#Problem 1
print('Problem 1:')
# Out:
# Problem 1:

# %%
import numpy as np
import math 
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %%
#Problem 2
print('Problem 2:')
# Out:
# Problem 2:

# %%
planet_x = ['Mercury', 'Venus', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
a1 = 365.25 
p1 = 1 
p2 = [87.96, 224.7, 689.97, 4332.82, 10775.6, 30687.15, 60190.03]

# %%
from HW8_support_function import kepler_3rd

# %%
q = kepler_3rd('Mercury', a1, p1, p2[0])
r = kepler_3rd('Venus', a1, p1, p2[1])
s = kepler_3rd('Mars', a1, p1, p2[2])
t = kepler_3rd('Jupiter', a1, p1, p2[3])
u = kepler_3rd('Saturn', a1, p1, p2[4])
v = kepler_3rd('Uranus', a1, p1, p2[5])
w = kepler_3rd('Neptune', a1, p1, p2[6])
# Out:
# The distance from the planet Mercury is 1.72 AU.
# The distance from the planet Venus is 4.4 AU.
# The distance from the planet Mars is 13.5 AU.
# The distance from the planet Jupiter is 84.8 AU.
# The distance from the planet Saturn is 210.89 AU.
# The distance from the planet Uranus is 600.57 AU.
# The distance from the planet Neptune is 1177.96 AU.

# %%
Calculated = [q, r, s, t, u, v, w]
Actual = [0.4, 0.7, 1.524, 5.2, 9.6, 19.2, 30.1]

# %%
x = np.linspace(0., 6., 7)

fig = plt.figure( figsize = (8,8) )

ax1 = fig.add_subplot(1, 1, 1)
ax2 = ax1.twinx()

ax1.plot(x, Calculated, color= 'blue' )
ax1.set_ylabel( 'Calulated', color='blue', fontsize=24, rotation = 90 )
ax1.tick_params( axis="both", labelsize=18, length = 7 , direction = 'in' )

ax2.plot(x, Actual, color='red')
ax2.set_ylabel('Actual', color='red',fontsize=24, rotation = 90)
ax2.tick_params( axis="y", labelsize=18 , length = 7 , direction = 'in' )

ax1.set_xticklabels([' ', 'Mercury', 'Venus', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune'], rotation = 90)
# Out:
# C:\Users\3daye\AppData\Local\Temp/ipykernel_11396/3267149948.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels([' ', 'Mercury', 'Venus', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune'], rotation = 90)
# [Text(-1.0, 0, ' '),
#  Text(0.0, 0, 'Mercury'),
#  Text(1.0, 0, 'Venus'),
#  Text(2.0, 0, 'Mars'),
#  Text(3.0, 0, 'Jupiter'),
#  Text(4.0, 0, 'Saturn'),
#  Text(5.0, 0, 'Uranus'),
#  Text(6.0, 0, 'Neptune'),
#  Text(7.0, 0, '')]

# %%
#Problem 3A
print('Problem 3A:')
# Out:
# Problem 3A:

# %%
x = np.linspace(12, 46, 100)
y = np.array((np.sin((2*np.pi*x)/16)) * (np.cos((2*np.pi*x)/8)))
z = np.array((np.cos((np.pi*x)/9)) * (np.sin((np.pi*x)/6)))

# %%
print(z.shape)
# Out:
# (100,)

# %%
print(y.shape)
# Out:
# (100,)

# %%
print(x.shape)
# Out:
# (100,)

# %%
fig = plt.figure( figsize = (8,8) )

ax1 = fig.add_subplot(1, 1, 1)
ax2 = ax1.twinx()
plt.xlim( 20, 40 )

ax1.plot( x, y, color= 'blue', linestyle = 'solid', label = 'Y')
ax1.set_ylabel( 'Y & Z', color='black', fontsize=30, rotation = 90 )
ax1.set_xlabel('x',fontsize=30)
ax1.tick_params( axis="both", labelsize=18, length = 2 , direction = 'out' )
plt.yticks( np.arange( -1.0, 2.1, step = 0.5 ) ,fontsize=30 ) 
plt.xticks( np.arange( 20, 40.1, 10 ) , fontsize=30 )

ax2.plot( x, z, color='red', linestyle = '--', label = 'Z')
plt.title( 'Problem 3A' , fontsize = 30 )
plt.legend( fontsize = 30 )

# %%
#Problem 3B
print('Problem 3B:')
# Out:
# Problem 3B:

# %%
for i in range(len(x)):
    if y in range(len(x)) > 0:
        print ( y )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11396/170351161.py in <module>
#       1 for i in range(len(x)):
# ----> 2     if y in range(len(x)) > 0:
#       3         print ( y )
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#Problem 3C
print('Problem 3C:')
# Out:
# Problem 3C:

# %%
data = np.zeros((100,100))
data1 = np.zeros((100,100))

# %%
#Problem 3D
print('Problem 3D:')
# Out:
# Problem 3D:

# %%
for i in data:
    for j in data1:
        y[i]*z[j] == data
        y[i]/z[j] == data1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11396/1966560262.py in <module>
#       1 for i in data:
#       2     for j in data1:
# ----> 3         y[i]*z[j] == data
#       4         y[i]/z[j] == data1
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
#Problem 3E
print('Problem 3E:')
# Out:
# Problem 3E:

# %%
print(z[(y > 0) & (y < 0.4)])
# Out:
# [ 0.05928302  0.65985135  0.61911206  0.53450496  0.41108132  0.25732122
#   0.0843866  -0.05332222  0.03326097  0.08586564  0.09809248  0.06725949
#  -0.84116213 -0.93568192 -0.16041503 -0.04010444 -0.24370869 -0.36858495
#  -0.48448597 -0.57890998 -0.64119195 -0.66346241  0.66211492  0.62989858
#   0.55922856  0.45870643  0.33952324  0.21445387  0.06566295  0.19268222
#   0.91687029  0.81379768]

# %%
print( x[(y>0) & (y<0.2)] , y[(z < 0) & (z > -0.16)])
# Out:
# [13.71717172 16.12121212 16.46464646 17.83838384 22.3030303  23.67676768
#  26.08080808 29.85858586 32.26262626 33.63636364 33.97979798 38.1010101
#  38.44444444 39.47474747 39.81818182 42.22222222 46.        ] [ 0.95508981  0.82696059  0.63436224  0.40520075 -0.10755438  0.1457365
#  -0.00793223 -0.13655009  0.08260377 -0.15670949 -0.03166405 -0.9649388
#  -0.18173622 -0.25709278 -0.26749679 -0.20237585 -0.06394043]

# %%
#Problem 3F
print( 'Problem 3F:')
# Out:
# Problem 3F:

# %%
#Problem 3G
print('Problem 3G:')
# Out:
# Problem 3G:

# %%
fig, ( ax1, ax2 ) = plt.subplots( 1, 2 , figsize = (16, 8 ))

fig.suptitle('Horizontally stacked scatter plots', fontsize = 24)

#start with the first one:

ax1.scatter( )
ax1.set_xlabel( ' Year ' , fontsize = 24 )
ax1.set_ylabel( ' Lead Avg ' , fontsize = 24 )
ax1.set_xticks( 1900 + np.arange( 4 ) * 20 )
ax1.set_xticklabels( 1900 + np.arange( 4 ) * 20 , fontsize = 14 )
ax1.tick_params( axis ='both', which ='both', length = 7 , direction = 'in' , labelsize=14 )

ax1.tick_params( axis ='both', which ='both', length = 7 , direction = 'in', labelsize=18 )

# %%
#Problem 4
print('Problem 4:')
# Out:
# Problem 4:

# %%
from HW8_support_function import piston

# %%
#Problem 5
print('Problem 5:')
# Out:
# Problem 5:

# %%
#End of homework 8
print('End of homework 8')
# Out:
# End of homework 8
