# %%
#Corine Smith, Homework 8, Mar 10 09:14:20 EST 2022
print( "Start of Homework 8")
# Out:
# Start of Homework 8

# %%
#Problem 1
print('Problem 1:')
# Out:
# Problem 1:

# %%
import numpy as np
import math 
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.mplot3d import Axes3D

# %%
#Problem 2
print('Problem 2:')
# Out:
# Problem 2:

# %%
planet_x = ['Mercury', 'Venus', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
a1 = 365.25 
p1 = 1 
p2 = [87.96, 224.7, 689.97, 4332.82, 10775.6, 30687.15, 60190.03]

# %%
from HW8_support_function import kepler_3rd

# %%
q = kepler_3rd('Mercury', a1, p1, p2[0])
r = kepler_3rd('Venus',a1, p1, p2[1])
s = kepler_3rd('Mars', a1, p1, p2[2])
t = kepler_3rd('Jupiter',a1, p1, p2[3])
u = kepler_3rd('Saturn',a1, p1, p2[4])
v = kepler_3rd('Uranus',a1, p1, p2[5])
w = kepler_3rd('Neptune',a1, p1, p2[6])
# Out:
# The distance from the planet Mercury is 1.72 AU.
# The distance from the planet Venus is 4.4 AU.
# The distance from the planet Mars is 13.5 AU.
# The distance from the planet Jupiter is 84.8 AU.
# The distance from the planet Saturn is 210.89 AU.
# The distance from the planet Uranus is 600.57 AU.
# The distance from the planet Neptune is 1177.96 AU.

# %%
Predicted = [q, r, s, t, u, v, w]
Real = [0.4, 0.7, 1.524, 5.2, 9.6, 19.2, 30.1]

# %%
x = np.linspace(0., 6., 7)

fig = plt.figure( figsize = (8,8) )

ax1 = fig.add_subplot(1, 1, 1)
ax2 = ax1.twinx()

ax1.plot(x, Predicted, color= 'blue' )
ax1.set_ylabel( 'Predicted(AU)', color='blue', fontsize=25, rotation = 90 )
ax1.tick_params( axis="both", labelsize=18, length = 7 , direction = 'in' )

ax2.plot(x, Real, color='red')
ax2.set_ylabel('Real(AU)', color='red',fontsize=25, rotation = 90)
ax2.tick_params( axis="y", labelsize=18 , length = 7 , direction = 'in' )

plt.title( 'Orbital distance of Planet to the Sun' , fontsize = 25 )
ax1.set_xticklabels([' ', 'Mercury', 'Venus', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune'], rotation = 90)
# Out:
# C:\Users\3daye\AppData\Local\Temp/ipykernel_10164/1127864573.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels([' ', 'Mercury', 'Venus', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune'], rotation = 90)
# [Text(-1.0, 0, ' '),
#  Text(0.0, 0, 'Mercury'),
#  Text(1.0, 0, 'Venus'),
#  Text(2.0, 0, 'Mars'),
#  Text(3.0, 0, 'Jupiter'),
#  Text(4.0, 0, 'Saturn'),
#  Text(5.0, 0, 'Uranus'),
#  Text(6.0, 0, 'Neptune'),
#  Text(7.0, 0, '')]

# %%
#Problem 3A
print('Problem 3A:')
# Out:
# Problem 3A:

# %%
x = np.linspace(12, 46, 100)
y = np.array((np.sin((2*np.pi*x)/16)) * (np.cos((2*np.pi*x)/8)))
z = np.array((np.cos((np.pi*x)/9)) * (np.sin((np.pi*x)/6)))

# %%
len(y)
len(x)
len(z)
# Out:
# 100

# %%
fig = plt.figure( figsize = (8,8) )
ax1 = fig.add_subplot(1, 1, 1)
ax2 = ax1.twinx()
plt.xlim( 20, 40 )

ax1.plot( x, y, color= 'blue', linestyle = 'solid', label = 'Y')
ax1.legend( fontsize = 35 )
ax1.set_ylabel( 'Y & Z', color='black', fontsize=35, rotation = 90 )
ax1.set_xlabel('x', fontsize=35)
ax1.tick_params( axis="both", labelsize=20, length = 2 , direction = 'out') 
ax1.set_yticks( np.arange( -1.0, 1.1, step = 0.5 ) ,fontsize=15) 
plt.xticks( np.arange( 20, 40.1, 10 ) , fontsize= 15)
    
ax2.plot( x, z, color='red', linestyle = '--', label = 'Z')
plt.title( 'Y & Z vs X' , fontsize = 35 )
ax2.legend( loc = 'upper left', fontsize = 35 )

plt.tick_params(labelright=False, right=False)

# %%
#Problem 3B
print('Problem 3B:')
# Out:
# Problem 3B:

# %%
for i in range(len(x)):
    if y[i] > 0 and z[i] > 0:
        print (x, y)
for j in range(len(y)):
    if z[j] > 0 and y[j] > 0:
        print(x, y)
for k in range(len(z)):
    if y[k] > 0 and z[k] > 0:
        print(x, y)
# Out:
# [12.         12.34343434 12.68686869 13.03030303 13.37373737 13.71717172
#  14.06060606 14.4040404  14.74747475 15.09090909 15.43434343 15.77777778
#  16.12121212 16.46464646 16.80808081 17.15151515 17.49494949 17.83838384
#  18.18181818 18.52525253 18.86868687 19.21212121 19.55555556 19.8989899
#  20.24242424 20.58585859 20.92929293 21.27272727 21.61616162 21.95959596
#  22.3030303  22.64646465 22.98989899 23.33333333 23.67676768 24.02020202
#  24.36363636 24.70707071 25.05050505 25.39393939 25.73737374 26.08080808
#  26.42424242 26.76767677 27.11111111 27.45454545 27.7979798  28.14141414
#  28.48484848 28.82828283 29.17171717 29.51515152 29.85858586 30.2020202
#  30.54545455 30.88888889 31.23232323 31.57575758 31.91919192 32.26262626
#  32.60606061 32.94949495 33.29292929 33.63636364 33.97979798 34.32323232
#  34.66666667 35.01010101 35.35353535 35.6969697  36.04040404 36.38383838
#  36.72727273 37.07070707 37.41414141 37.75757576 38.1010101  38.44444444
# ...

# %%
#Problem 3C
print('Problem 3C:')
# Out:
# Problem 3C:

# %%
data = np.zeros((100,100))
data2 = np.zeros((100,100))

# %%
#Problem 3D
print('Problem 3D:')
# Out:
# Problem 3D:

# %%
for i in range(len(y)):
    for j in range(len(z)):
        data[i,j] =  y[i]*z[j]
        data2[i,j] = y[i]/z[j]

# %%
#Problem 3E
print('Problem 3E:')
# Out:
# Problem 3E:

# %%
print(z[(y > 0) & (y < 0.4)])
# Out:
# [ 0.05928302  0.65985135  0.61911206  0.53450496  0.41108132  0.25732122
#   0.0843866  -0.05332222  0.03326097  0.08586564  0.09809248  0.06725949
#  -0.84116213 -0.93568192 -0.16041503 -0.04010444 -0.24370869 -0.36858495
#  -0.48448597 -0.57890998 -0.64119195 -0.66346241  0.66211492  0.62989858
#   0.55922856  0.45870643  0.33952324  0.21445387  0.06566295  0.19268222
#   0.91687029  0.81379768]

# %%
print([x[(y>0) & (y<0.2)] , y[(z < 0) & (z > -0.16)]])
# Out:
# [array([13.71717172, 16.12121212, 16.46464646, 17.83838384, 22.3030303 ,
#        23.67676768, 26.08080808, 29.85858586, 32.26262626, 33.63636364,
#        33.97979798, 38.1010101 , 38.44444444, 39.47474747, 39.81818182,
#        42.22222222, 46.        ]), array([ 0.95508981,  0.82696059,  0.63436224,  0.40520075, -0.10755438,
#         0.1457365 , -0.00793223, -0.13655009,  0.08260377, -0.15670949,
#        -0.03166405, -0.9649388 , -0.18173622, -0.25709278, -0.26749679,
#        -0.20237585, -0.06394043])]

# %%
#Problem 3F
print( 'Problem 3F:')
# Out:
# Problem 3F:

# %%
datatr = np.transpose(data)
print(datatr)
# Out:
# [[ 1.22464680e-16  1.16964767e-16  1.01273463e-16 ...  5.47271671e-17
#    2.59685977e-17  2.75781082e-31]
#  [-7.02610605e-02 -6.71056227e-02 -5.81031277e-02 ... -3.13983493e-02
#   -1.48988363e-02 -1.58222528e-16]
#  [-9.85576643e-02 -9.41314206e-02 -8.15033038e-02 ... -4.40435705e-02
#   -2.08991224e-02 -2.21944314e-16]
#  ...
#  [ 9.80701785e-01  9.36658279e-01  8.11001722e-01 ...  4.38257222e-01
#    2.07957512e-01  2.20846533e-15]
#  [ 9.16870290e-01  8.75693468e-01  7.58215591e-01 ...  4.09732125e-01
#    1.94422063e-01  2.06472169e-15]
#  [ 8.13797681e-01  7.77249870e-01  6.72978607e-01 ...  3.63670911e-01
#    1.72565548e-01  1.83261007e-15]]

# %%
#Problem 3G
print('Problem 3G:')
# Out:
# Problem 3G:

# %%
fig, ax = plt.subplots( figsize = ( 8, 8 ) )

fig.suptitle('Col 2 datatr vs Col 42 data2', fontsize = 25)

ax.scatter( datatr, data2)
ax.set_xlabel( 'Y' , fontsize = 25 )
ax.set_ylabel( 'Z' , fontsize = 25 , rotation = 90)
ax.set_xticks( np.arange( -1.0, 1.1, 0.5), fontsize = 14)
ax.set_xticklabels( np.arange( -1.0, 1.1, 0.5) , fontsize = 14 )
ax.tick_params( axis ='both', which ='both', length = 5 , direction = 'out' , labelsize=14 )

# %%
#print(data2[:42])
#print(datatr[:2])

# %%
#Bug note-This scatter plot shows a straight line at 0, but upon printing the col 2 of datatr and col 42 of data2, the values are very small and when plotted withe these y axis parameters appear as zero. I am unsure if this is because there is a bug in my data arrays or if this was coded correctly and how it should look. I didnt have time to really verify this before this assignment was due.

# %%
#Problem 4
print('Problem 4A:')
# Out:
# Problem 4A:

# %%
from HW8_support_function import piston

# %%
V = np.linspace(1,0.1,40)
P0 = 1
T0 = 300
V0 = 1
gamma = 1.4
Piston = piston(V, P0, V0, T0, gamma)
print(Piston[0,:])
print(Piston[1,:])
print(Piston[2,:])
# Out:
# [ 1.          1.03322638  1.06839128  1.10565892  1.14521198  1.18725421
#   1.23201349  1.27974546  1.33073776  1.38531513  1.4438454   1.50674676
#   1.5744965   1.64764158  1.72681158  1.81273449  1.90625633  2.00836556
#   2.1202236   2.24320358  2.37893972  2.529391    2.69692413  2.88442283
#   3.09543367  3.33436338  3.60674976  3.91964     4.28212883  4.70614014
#   5.20758905  5.80815609  6.53807968  7.44070903  8.58024027 10.0555234
#  12.02621435 14.76609479 18.78247059 25.11886432]
# [1.         0.97692308 0.95384615 0.93076923 0.90769231 0.88461538
#  0.86153846 0.83846154 0.81538462 0.79230769 0.76923077 0.74615385
#  0.72307692 0.7        0.67692308 0.65384615 0.63076923 0.60769231
#  0.58461538 0.56153846 0.53846154 0.51538462 0.49230769 0.46923077
#  0.44615385 0.42307692 0.4        0.37692308 0.35384615 0.33076923
#  0.30769231 0.28461538 0.26153846 0.23846154 0.21538462 0.19230769
#  0.16923077 0.14615385 0.12307692 0.1       ]
# ...

# %%
#Problem 4B
print('Problem 4B:')
# Out:
# Problem 4B:

# %%
fig,ax =plt.subplots(1,1, figsize =(16,16))
ax = plt.axes(projection='3d')

P = Piston[0,:]
V = Piston[1,:]
T = Piston[2,:]

ax.set_xlabel('Volume (L)', fontsize = 25 )
ax.set_ylabel('Pressure (ATM)', fontsize = 25 )
ax.set_zlabel('Temperature (K)', fontsize = 25 )

ax = fig.gca(projection='3d')
ax.plot(P, V, T, label='Gas Volume vs Pressure vs Temperature')
ax.legend( fontsize = 25 )
plt.savefig( 'HW8_CSmith_Problem4_Plot.png', format = 'png', dpi = 200, bbox_inches = 'tight', pad_inches = 0.3 )
# Out:
# C:\Users\3daye\AppData\Local\Temp/ipykernel_22896/2993739026.py:12: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
#Problem 5
print('Problem 5:')
# Out:
# Problem 5:

# %%
#End of homework 8
print('End of homework 8')
# Out:
# End of homework 8
